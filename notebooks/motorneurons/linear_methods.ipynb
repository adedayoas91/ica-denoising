# %% [markdown]
# # Motorneurons Linear BSS Analysis
#
# This notebook runs the shared linear BSS workflow for FastICA, Infomax, SOBI, and JADE.
# Choose `DATASET_KEY` and `METHODS_TO_RUN` in the configuration cell. Outputs are saved under
# `outputs/linear/<dataset_group>/<data_name>/<method>/` when `SAVE_OUTPUTS = True`.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np

candidates = [Path.cwd(), *Path.cwd().parents]
PROJECT_ROOT = next(
    p
    for p in candidates
    if (p / "pyproject.toml").exists() and (p / "src" / "bss_notebook.py").exists()
)
SRC_DIR = PROJECT_ROOT / "src"
CORE_DIR = SRC_DIR / "core"
for path in (SRC_DIR, CORE_DIR):
    path_str = str(path)
    if path_str not in sys.path:
        sys.path.insert(0, path_str)

from bss_notebook import (
    BSS_METHODS,
    available_datasets,
    load_traces,
    output_directory,
    run_many_methods,
    summarize_results,
)

plt.rcParams.update({
    "figure.figsize": (12, 4),
    "axes.spines.top": False,
    "axes.spines.right": False,
})
PROJECT_ROOT
# Out:
# PosixPath('/Users/sadiqadedayo/Documents/projects/ICA/ica-denoising')

# %%
available_datasets(PROJECT_ROOT)
# Out:
#                                     key         group  \
# 0         motorneurons/fish3_trace2_dff  motorneurons
# 1             motorneurons/gcM_restored  motorneurons
# 2  v2a-RSNs/220127_F4_run2_fluorescence      v2a-RSNs
# 3    v2a-RSNs/220127_F4_run2_spike_rate      v2a-RSNs
# 4  v2a-RSNs/220210_F1_run6_fluorescence      v2a-RSNs
# 5    v2a-RSNs/220210_F1_run6_spike_rate      v2a-RSNs
#
#                      data_name  \
# 0             fish3_trace2_dff
# 1                 gcM_restored
# 2  220127_F4_run2_fluorescence
# 3    220127_F4_run2_spike_rate
# 4  220210_F1_run6_fluorescence
# 5    220210_F1_run6_spike_rate
#
#                                           trace_path  exists  \
# 0  /Users/sadiqadedayo/Documents/projects/ICA/ica...    True
# 1  /Users/sadiqadedayo/Documents/projects/ICA/ica...    True
# 2  /Users/sadiqadedayo/Documents/projects/ICA/ica...    True
# 3  /Users/sadiqadedayo/Documents/projects/ICA/ica...    True
# 4  /Users/sadiqadedayo/Documents/projects/ICA/ica...    True
# 5  /Users/sadiqadedayo/Documents/projects/ICA/ica...    True
#
#    default_n_components  sample_rate_hz                         notes
# 0                    11             4.0      Motorneuron dF/F traces.
# 1                    11             4.0  Restored motorneuron traces.
# 2                    40            30.0  V2a RSN fluorescence traces.
# 3                    40            30.0    V2a RSN spike-rate traces.
# 4                    40            30.0  V2a RSN fluorescence traces.
# 5                    40            30.0    V2a RSN spike-rate traces.

# %%
# Dataset and method selection
DATASET_KEY = "motorneurons/fish3_trace2_dff"

# Use list(BSS_METHODS) to run all four methods, or choose a subset such as ["fastica"].
METHODS_TO_RUN = list(BSS_METHODS)

# None uses the dataset default from bss_notebook.dataset_registry().
N_COMPONENTS = None
DECOMPOSITION_TOL = 0.0001
DECOMPOSITION_MAX_ITER = 500
DECOMPOSITION_RANDOM_STATE = 0

# Fill after inspecting components. Keys are method names; values are component indices to reject.
REJECT_COMPONENTS_BY_METHOD = {method: [] for method in BSS_METHODS}

# Keep False until component rejection choices are final.
SAVE_OUTPUTS = False

# %%
dataset, traces = load_traces(DATASET_KEY, PROJECT_ROOT)
n_components = min(N_COMPONENTS or dataset.default_n_components or min(traces.shape), *traces.shape)
n_neurons, n_frames = traces.shape

print(f"dataset: {dataset.key}")
print(f"trace file: {dataset.trace_path.relative_to(PROJECT_ROOT)}")
print(f"traces: neurons={n_neurons}, frames={n_frames}")
print(f"methods: {METHODS_TO_RUN}")
print(f"n_components: {n_components}")
for method in METHODS_TO_RUN:
    out_dir = output_directory(method, dataset.data_name, PROJECT_ROOT, dataset_group=dataset.group)
    print(f"{method} output dir: {out_dir.relative_to(PROJECT_ROOT)}")
# Out:
# dataset: motorneurons/fish3_trace2_dff
# trace file: data/motorneurons/fish3_trace2_dff.npy
# traces: neurons=11, frames=1000
# methods: ['fastica', 'infomax', 'sobi', 'jade']
# n_components: 11
# fastica output dir: outputs/linear/motorneurons/fish3_trace2_dff/fastica
# infomax output dir: outputs/linear/motorneurons/fish3_trace2_dff/infomax
# sobi output dir: outputs/linear/motorneurons/fish3_trace2_dff/sobi
# jade output dir: outputs/linear/motorneurons/fish3_trace2_dff/jade

# %%
fig, ax = plt.subplots(figsize=(14, 3))
time_slice = slice(0, min(600, n_frames))
offset = np.nanstd(traces[:, time_slice]) * 3
if not np.isfinite(offset) or offset == 0:
    offset = 1.0
for neuron_idx in range(min(6, n_neurons)):
    ax.plot(
        np.arange(time_slice.start, time_slice.stop),
        traces[neuron_idx, time_slice] + neuron_idx * offset,
        lw=0.8,
        label=f"neuron {neuron_idx}",
    )
ax.set_title("Raw traces")
ax.set_xlabel("frame")
ax.legend(loc="upper right", ncols=3);

# %%
results = run_many_methods(
    dataset_key=DATASET_KEY,
    methods=METHODS_TO_RUN,
    n_components=N_COMPONENTS,
    reject_components_by_method=REJECT_COMPONENTS_BY_METHOD,
    save_outputs=SAVE_OUTPUTS,
    project_root=PROJECT_ROOT,
    tol=DECOMPOSITION_TOL,
    max_iter=DECOMPOSITION_MAX_ITER,
    random_state=DECOMPOSITION_RANDOM_STATE,
)

summarize_results(results)
# Out:
#     method                    dataset_key         data_name dataset_group  \
# 0  fastica  motorneurons/fish3_trace2_dff  fish3_trace2_dff  motorneurons
# 1  infomax  motorneurons/fish3_trace2_dff  fish3_trace2_dff  motorneurons
# 2     sobi  motorneurons/fish3_trace2_dff  fish3_trace2_dff  motorneurons
# 3     jade  motorneurons/fish3_trace2_dff  fish3_trace2_dff  motorneurons
#
#   input_shape components_shape cleaned_shape_frames_by_neurons  \
# 0  (11, 1000)       (1000, 11)                      (1000, 11)
# 1  (11, 1000)       (1000, 11)                      (1000, 11)
# 2  (11, 1000)       (1000, 11)                      (1000, 11)
# 3  (11, 1000)       (1000, 11)                      (1000, 11)
#
#                                           output_dir  saved
# 0  /Users/sadiqadedayo/Documents/projects/ICA/ica...  False
# 1  /Users/sadiqadedayo/Documents/projects/ICA/ica...  False
# 2  /Users/sadiqadedayo/Documents/projects/ICA/ica...  False
# 3  /Users/sadiqadedayo/Documents/projects/ICA/ica...  False

# %%
component_count = min(8, n_components)
fig, axes = plt.subplots(len(results), 1, figsize=(14, 2.0 * len(results)), sharex=True)
if len(results) == 1:
    axes = [axes]
for ax, (method, result) in zip(axes, results.items()):
    for comp_idx in range(component_count):
        ax.plot(result.ic_comps[:, comp_idx] + comp_idx * 3, lw=0.7, label=f"IC {comp_idx}")
    ax.set_title(f"{method.upper()} first {component_count} components")
axes[-1].set_xlabel("frame");

# %%
fig, axes = plt.subplots(len(results), 1, figsize=(14, 2.3 * len(results)), sharex=True)
if len(results) == 1:
    axes = [axes]
neuron_idx = 0
for ax, (method, result) in zip(axes, results.items()):
    ax.plot(traces[neuron_idx, time_slice], lw=0.8, label="raw", color="red", alpha=0.65)
    ax.plot(
        result.cleaned[time_slice, neuron_idx],
        lw=0.8,
        label=f"{method} cleaned",
        color="blue",
        alpha=0.8,
    )
    ax.set_title(f"Raw vs cleaned, neuron {neuron_idx}, {method}")
    ax.legend(loc="upper right")
axes[-1].set_xlabel("frame");

# %%
for method, result in results.items():
    if result.saved_paths:
        print(f"{method}:")
        for label, path in result.saved_paths.items():
            print(f"  {label}: {path.relative_to(PROJECT_ROOT)}")
    else:
        print(
            f"{method}: not saved; set SAVE_OUTPUTS = True and rerun the decomposition cell "
            f"to write outputs under {result.output_dir.relative_to(PROJECT_ROOT)}"
        )
# Out:
# fastica: not saved; set SAVE_OUTPUTS = True and rerun the decomposition cell to write outputs under outputs/linear/motorneurons/fish3_trace2_dff/fastica
# infomax: not saved; set SAVE_OUTPUTS = True and rerun the decomposition cell to write outputs under outputs/linear/motorneurons/fish3_trace2_dff/infomax
# sobi: not saved; set SAVE_OUTPUTS = True and rerun the decomposition cell to write outputs under outputs/linear/motorneurons/fish3_trace2_dff/sobi
# jade: not saved; set SAVE_OUTPUTS = True and rerun the decomposition cell to write outputs under outputs/linear/motorneurons/fish3_trace2_dff/jade
