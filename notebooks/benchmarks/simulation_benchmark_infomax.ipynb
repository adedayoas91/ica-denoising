# %% [markdown]
# # Ground-truth simulation benchmark - Infomax split
#
# This notebook is a method-specific split of `simulation_benchmark_all_methods.ipynb`. It runs only `infomax` BSS methods from `configs/simulation.core.json` and writes to `outputs/simulation/core_1000_infomax/`, so it can run in parallel with the other split notebooks without sharing replicate manifests.

# %%
from __future__ import annotations

from dataclasses import replace
import json
import os
import sys
from pathlib import Path


def find_repo_root(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()
    candidates = (start, *start.parents)
    for path in candidates:
        if (path / "pyproject.toml").exists() and (path / "src" / "ica_denoising").exists():
            return path
    raise RuntimeError("Could not find the ica-denoising repository root.")


REPO_ROOT = find_repo_root()
os.chdir(REPO_ROOT)
os.environ.setdefault("MPLCONFIGDIR", str(REPO_ROOT / ".cache" / "matplotlib"))
(REPO_ROOT / ".cache" / "matplotlib").mkdir(parents=True, exist_ok=True)

SRC = REPO_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))


def repo_display_path(path: str | Path) -> str:
    path = Path(path)
    if not path.is_absolute():
        return str(path)
    try:
        return str(path.relative_to(REPO_ROOT))
    except ValueError:
        return str(path)

import matplotlib
if "ipykernel" in sys.modules:
    try:
        from IPython import get_ipython
        ip = get_ipython()
        if ip is not None:
            ip.run_line_magic("matplotlib", "inline")
    except Exception:
        pass
else:
    matplotlib.use("Agg")
SHOW_FIGURES = "ipykernel" in sys.modules

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from ica_denoising.simulation import (
    import_completed_replicates_from_benchmark,
    load_config,
    run_benchmark,
)
from ica_denoising.simulation.reporting import (
    collect_metric_table,
    paired_vs_raw,
    summarize_graph_recovery,
)
from ica_denoising.simulation.validate import validate_benchmark

sns.set_theme(style="whitegrid", context="talk")
print(f"Repository root: {REPO_ROOT}")
# Out:
# Repository root: /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising

# %% [markdown]
# ## Run configuration

# %%
CONFIG_PATH = REPO_ROOT / "configs" / "simulation.core.json"
METHOD_SPLIT_NAME = 'infomax'
METHODS_TO_RUN = ('infomax',)

# Keep these as None to use the selected config. For a quick single replicate,
# set SCENARIOS = ["S0"] and SEEDS = [0].
SCENARIOS: list[str] | None = None
SEEDS: list[int] | None = None

RUN_BENCHMARK = True
DRY_RUN = False
RESUME = True

MAIN_GRAPH_ESTIMATORS = ("cgc", "cgc_star", "pcmci", "jpcmciplus")
SUPPLEMENTARY_GRAPH_ESTIMATORS = ("var",)
IMPORT_COMPLETED_FROM_UNSPLIT = False
UNSPLIT_BENCHMARK_VERSION = "core_1000"

cfg = load_config(CONFIG_PATH)
cfg = replace(
    cfg,
    benchmark_version=f"{cfg.benchmark_version}_{METHOD_SPLIT_NAME}",
    bss=replace(cfg.bss, methods=METHODS_TO_RUN),
)
benchmark_root = REPO_ROOT / cfg.run.output_dir / cfg.benchmark_version
unsplit_benchmark_root = REPO_ROOT / cfg.run.output_dir / UNSPLIT_BENCHMARK_VERSION
summary_dir = benchmark_root / "summary"
figure_dir = benchmark_root / "figures"

print(json.dumps({
    "config": str(CONFIG_PATH.relative_to(REPO_ROOT)),
    "method_split": METHOD_SPLIT_NAME,
    "methods": list(cfg.bss.methods),
    "benchmark_version": cfg.benchmark_version,
    "benchmark_root": str(benchmark_root.relative_to(REPO_ROOT)),
    "import_source": str(unsplit_benchmark_root.relative_to(REPO_ROOT)),
    "import_completed_from_unsplit": IMPORT_COMPLETED_FROM_UNSPLIT,
    "scenarios": SCENARIOS or "from config",
    "seeds": SEEDS or "from config",
    "dry_run": DRY_RUN,
    "resume": RESUME,
    "main_graph_estimators": list(MAIN_GRAPH_ESTIMATORS),
    "supplementary_graph_estimators": list(SUPPLEMENTARY_GRAPH_ESTIMATORS),
}, indent=2))
# Out:
# {
#   "config": "configs/simulation.core.json",
#   "method_split": "infomax",
#   "methods": [
#     "infomax"
#   ],
#   "benchmark_version": "core_1000_infomax",
#   "benchmark_root": "outputs/simulation/core_1000_infomax",
#   "import_source": "outputs/simulation/core_1000",
#   "import_completed_from_unsplit": false,
#   "scenarios": "from config",
#   "seeds": "from config",
#   "dry_run": false,
#   "resume": true,
#   "main_graph_estimators": [
#     "cgc",
#     "cgc_star",
#     "pcmci",
#     "jpcmciplus"
#   ],
#   "supplementary_graph_estimators": [
#     "var"
#   ]
# }

# %% [markdown]
# ## Execute benchmark

# %%
def format_progress_bar(completed, total, width=28):
    total = max(int(total), 1)
    completed = min(max(int(completed), 0), total)
    filled = int(round(width * completed / total))
    return f"[{'#' * filled}{'.' * (width - filled)}] {completed}/{total}"


def make_progress_callback(label):
    last = {"line": ""}

    def callback(event):
        status = str(event.get("event", ""))
        scenario = event.get("scenario_id", "?")
        seed = event.get("seed", "?")
        completed = int(event.get("completed", 0))
        total = int(event.get("total", 0))
        line = f"{label}: {format_progress_bar(completed, total)} {status} {scenario}/seed_{seed}"
        padding = " " * max(0, len(last["line"]) - len(line))
        print("\r" + line + padding, end="", flush=True)
        last["line"] = line
        if status not in {"start"}:
            print("", flush=True)
            last["line"] = ""

    return callback


if IMPORT_COMPLETED_FROM_UNSPLIT and not DRY_RUN:
    import_report = import_completed_replicates_from_benchmark(
        unsplit_benchmark_root,
        cfg,
        scenarios=SCENARIOS,
        seeds=SEEDS,
        resume=RESUME,
        progress_callback=make_progress_callback("import"),
    )
else:
    import_report = {}

if import_report:
    print("Import summary:", json.dumps(import_report, indent=2))

if RUN_BENCHMARK:
    planned_paths = run_benchmark(
        cfg,
        scenarios=SCENARIOS,
        seeds=SEEDS,
        resume=RESUME,
        dry_run=DRY_RUN,
        progress_callback=make_progress_callback("run"),
    )
else:
    planned_paths = sorted(benchmark_root.glob("*/seed_*"))

print(f"{'Planned' if DRY_RUN else 'Available'} replicate(s): {len(planned_paths)}")
for path in planned_paths:
    print(repo_display_path(path))
# Out:
# run: [............................] 0/240 start S0/seed_0
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [............................] 1/240 done S0/seed_0
# run: [............................] 1/240 start S0/seed_1
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [............................] 2/240 done S0/seed_1
# run: [............................] 2/240 start S0/seed_2
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [............................] 3/240 done S0/seed_2
# run: [............................] 3/240 start S0/seed_3
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [............................] 4/240 done S0/seed_3
# run: [............................] 4/240 start S0/seed_4
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 5/240 done S0/seed_4
# run: [#...........................] 5/240 start S0/seed_5
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 6/240 done S0/seed_5
# run: [#...........................] 6/240 start S0/seed_6
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 7/240 done S0/seed_6
# run: [#...........................] 7/240 start S0/seed_7
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 8/240 done S0/seed_7
# run: [#...........................] 8/240 start S0/seed_8
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 9/240 done S0/seed_8
# run: [#...........................] 9/240 start S0/seed_9
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 10/240 done S0/seed_9
# run: [#...........................] 10/240 start S0/seed_10
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 11/240 done S0/seed_10
# run: [#...........................] 11/240 start S0/seed_11
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#...........................] 12/240 done S0/seed_11
# run: [#...........................] 12/240 start S0/seed_12
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 13/240 done S0/seed_12
# run: [##..........................] 13/240 start S0/seed_13
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 14/240 done S0/seed_13
# run: [##..........................] 14/240 start S0/seed_14
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 15/240 done S0/seed_14
# run: [##..........................] 15/240 start S0/seed_15
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 16/240 done S0/seed_15
# run: [##..........................] 16/240 start S0/seed_16
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 17/240 done S0/seed_16
# run: [##..........................] 17/240 start S0/seed_17
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 18/240 done S0/seed_17
# run: [##..........................] 18/240 start S0/seed_18
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 19/240 done S0/seed_18
# run: [##..........................] 19/240 start S0/seed_19
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 20/240 done S0/seed_19
# run: [##..........................] 20/240 start S0/seed_20
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [##..........................] 21/240 done S0/seed_20
# run: [##..........................] 21/240 start S0/seed_21
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 22/240 done S0/seed_21
# run: [###.........................] 22/240 start S0/seed_22
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 23/240 done S0/seed_22
# run: [###.........................] 23/240 start S0/seed_23
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 24/240 done S0/seed_23
# run: [###.........................] 24/240 start S0/seed_24
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 25/240 done S0/seed_24
# run: [###.........................] 25/240 start S0/seed_25
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 26/240 done S0/seed_25
# run: [###.........................] 26/240 start S0/seed_26
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 27/240 done S0/seed_26
# run: [###.........................] 27/240 start S0/seed_27
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 28/240 done S0/seed_27
# run: [###.........................] 28/240 start S0/seed_28
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [###.........................] 29/240 done S0/seed_28
# run: [###.........................] 29/240 start S0/seed_29
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 30/240 done S0/seed_29
# run: [####........................] 30/240 start S1/seed_0
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 31/240 done S1/seed_0
# run: [####........................] 31/240 start S1/seed_1
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 32/240 done S1/seed_1
# run: [####........................] 32/240 start S1/seed_2
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 33/240 done S1/seed_2
# run: [####........................] 33/240 start S1/seed_3
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 34/240 done S1/seed_3
# run: [####........................] 34/240 start S1/seed_4
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 35/240 done S1/seed_4
# run: [####........................] 35/240 start S1/seed_5
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 36/240 done S1/seed_5
# run: [####........................] 36/240 start S1/seed_6
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 37/240 done S1/seed_6
# run: [####........................] 37/240 start S1/seed_7
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [####........................] 38/240 done S1/seed_7
# run: [####........................] 38/240 start S1/seed_8
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 39/240 done S1/seed_8
# run: [#####.......................] 39/240 start S1/seed_9
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 40/240 done S1/seed_9
# run: [#####.......................] 40/240 start S1/seed_10
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 41/240 done S1/seed_10
# run: [#####.......................] 41/240 start S1/seed_11
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 42/240 done S1/seed_11
# run: [#####.......................] 42/240 start S1/seed_12
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 43/240 done S1/seed_12
# run: [#####.......................] 43/240 start S1/seed_13
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 44/240 done S1/seed_13
# run: [#####.......................] 44/240 start S1/seed_14
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 45/240 done S1/seed_14
# run: [#####.......................] 45/240 start S1/seed_15
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 46/240 done S1/seed_15
# run: [#####.......................] 46/240 start S1/seed_16
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#####.......................] 47/240 done S1/seed_16
# run: [#####.......................] 47/240 start S1/seed_17
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 48/240 done S1/seed_17
# run: [######......................] 48/240 start S1/seed_18
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 49/240 done S1/seed_18
# run: [######......................] 49/240 start S1/seed_19
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 50/240 done S1/seed_19
# run: [######......................] 50/240 start S1/seed_20
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 51/240 done S1/seed_20
# run: [######......................] 51/240 start S1/seed_21
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 52/240 done S1/seed_21
# run: [######......................] 52/240 start S1/seed_22
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 53/240 done S1/seed_22
# run: [######......................] 53/240 start S1/seed_23
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 54/240 done S1/seed_23
# run: [######......................] 54/240 start S1/seed_24
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [######......................] 55/240 done S1/seed_24
# run: [######......................] 55/240 start S1/seed_25
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#######.....................] 56/240 done S1/seed_25
# run: [#######.....................] 56/240 start S1/seed_26
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#######.....................] 57/240 done S1/seed_26
# run: [#######.....................] 57/240 start S1/seed_27
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#######.....................] 58/240 done S1/seed_27
# run: [#######.....................] 58/240 start S1/seed_28
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#######.....................] 59/240 done S1/seed_28
# run: [#######.....................] 59/240 start S1/seed_29
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3023: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/sadiqadedayo/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3024: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# run: [#######.....................] 60/240 done S1/seed_29
# run: [#######.....................] 61/240 done S2/seed_0
# run: [#######.....................] 62/240 done S2/seed_1
# run: [#######.....................] 63/240 done S2/seed_2
# run: [#######.....................] 64/240 done S2/seed_3
# run: [########....................] 65/240 done S2/seed_4
# run: [########....................] 66/240 done S2/seed_5
# run: [########....................] 67/240 done S2/seed_6
# run: [########....................] 68/240 done S2/seed_7
# run: [########....................] 69/240 done S2/seed_8
# run: [########....................] 70/240 done S2/seed_9
# run: [########....................] 71/240 done S2/seed_10
# run: [########....................] 72/240 done S2/seed_11
# run: [#########...................] 73/240 done S2/seed_12
# run: [#########...................] 74/240 done S2/seed_13
# run: [#########...................] 75/240 done S2/seed_14
# run: [#########...................] 76/240 done S2/seed_15
# run: [#########...................] 77/240 done S2/seed_16
# run: [#########...................] 78/240 done S2/seed_17
# run: [#########...................] 79/240 done S2/seed_18
# run: [#########...................] 79/240 start S2/seed_19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 44
#      40 if import_report:
#      41     print("Import summary:", json.dumps(import_report, indent=2))
#      42
#      43 if RUN_BENCHMARK:
# ---> 44     planned_paths = run_benchmark(
#      45         cfg,
#      46         scenarios=SCENARIOS,
#      47         seeds=SEEDS,
#
# File ~/Documents/projects/ICA/ica-denoising/src/ica_denoising/simulation/runner.py:719, in run_benchmark(cfg, scenarios, seeds, resume, dry_run, progress_callback)
#     717     planned.append(_extend_replicate_graphs(cfg, scenario, seed))
#     718 else:
# --> 719     planned.append(run_replicate(cfg, scenario, seed))
#     720 completed += 1
#     721 _notify_progress(
#     722     progress_callback,
#     723     event="done",
#    (...)    729     path=out_dir,
#     730 )
#
# File ~/Documents/projects/ICA/ica-denoising/src/ica_denoising/simulation/runner.py:297, in run_replicate(cfg, scenario, seed)
#     295 for estimator in estimators:
#     296     try:
# --> 297         est = _graph_estimate_for_variant(estimator, variant.traces, cfg)
#     298     except Exception as exc:
#     299         failures.append(
#     300             {"variant": variant.variant_id, "estimator": estimator, "error": str(exc)}
#     301         )
#
# File ~/Documents/projects/ICA/ica-denoising/src/ica_denoising/simulation/runner.py:124, in _graph_estimate_for_variant(estimator, traces, cfg)
#     122     return fn(traces, orders=est_cfg.var_orders)
#     123 if estimator in ("pcmci", "jpcmciplus"):
# --> 124     return fn(
#     125         traces,
#     126         tau_max=est_cfg.n_lags,
#     127         alpha=est_cfg.pcmci_alpha,
#     128     )
#     129 return fn(traces)
#
# File ~/Documents/projects/ICA/ica-denoising/src/csl/experiments/simulation_adapters.py:255, in estimate_jpcmciplus(traces, tau_max, alpha)
#     248 node_classification = {i: "system" for i in range(x.shape[1])}
#     249 jpcmciplus = JPCMCIplus(
#     250     dataframe=dataframe,
#     251     cond_ind_test=ParCorrMult(significance="analytic"),
#     252     node_classification=node_classification,
#     253     verbosity=0,
#     254 )
# --> 255 results = jpcmciplus.run_jpcmciplus(
#     256     tau_min=0,
#     257     tau_max=tau_max,
#     258     pc_alpha=alpha,
#     259 )
#     260 graph = results["graph"]
#     261 d = x.shape[1]
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/jpcmciplus.py:360, in JPCMCIplus.run_jpcmciplus(self, contemp_collider_rule, link_assumptions, tau_min, tau_max, pc_alpha, conflict_resolution, reset_lagged_links, max_conds_dim, max_combinations, max_conds_py, max_conds_px, max_conds_px_lagged, fdr_method)
#     357 dummy_system_results_copy = deepcopy(dummy_system_results)
#     359 # step 4:
# --> 360 system_skeleton_results = self.discover_system_system_links(link_assumptions=_link_assumptions,
#     361                                                             lagged_context_dummy_parents=lagged_context_dummy_parents,
#     362                                                             tau_min=tau_min,
#     363                                                             tau_max=tau_max,
#     364                                                             pc_alpha=pc_alpha,
#     365                                                             reset_lagged_links=reset_lagged_links,
#     366                                                             max_conds_dim=max_conds_dim,
#     367                                                             max_conds_py=max_conds_py,
#     368                                                             max_conds_px=max_conds_px,
#     369                                                             max_conds_px_lagged=max_conds_px_lagged,
#     370                                                             fdr_method=fdr_method)
#     372 # orientation phase
#     373 colliders_step_results = self._pcmciplus_collider_phase(
#     374     system_skeleton_results['graph'], system_skeleton_results['sepsets'],
#     375     lagged_context_dummy_parents, pc_alpha,
#     376     tau_min, tau_max, max_conds_py, max_conds_px, max_conds_px_lagged,
#     377     conflict_resolution, contemp_collider_rule)
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/jpcmciplus.py:730, in JPCMCIplus.discover_system_system_links(self, link_assumptions, lagged_context_dummy_parents, tau_min, tau_max, pc_alpha, reset_lagged_links, max_conds_dim, max_conds_py, max_conds_px, max_conds_px_lagged, fdr_method)
#     727     if system_links is not None:
#     728         print("\nWith link_assumptions = %s" % str(_int_link_assumptions))
# --> 730 skeleton_results = self._pcmciplus_mci_skeleton_phase(
#     731     lagged_context_dummy_parents, _int_link_assumptions, pc_alpha,
#     732     tau_min, tau_max, max_conds_dim, None,
#     733     max_conds_py, max_conds_px, max_conds_px_lagged,
#     734     reset_lagged_links, fdr_method,
#     735     self.p_matrix, self.val_matrix
#     736 )
#     738 return skeleton_results
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/pcmci.py:2332, in PCMCI._pcmciplus_mci_skeleton_phase(self, lagged_parents, link_assumptions, pc_alpha, tau_min, tau_max, max_conds_dim, max_combinations, max_conds_py, max_conds_px, max_conds_px_lagged, reset_lagged_links, fdr_method, p_matrix, val_matrix)
#    2328     max_combinations = np.inf
#    2330 initial_graph = self._dict_to_graph(links_for_pc, tau_max=tau_max)
# -> 2332 skeleton_results = self._pcalg_skeleton(
#    2333     initial_graph=initial_graph,
#    2334     lagged_parents=lagged_parents,
#    2335     mode='contemp_conds',
#    2336     pc_alpha=pc_alpha,
#    2337     tau_min=tau_min,
#    2338     tau_max=tau_max,
#    2339     max_conds_dim=max_conds_dim,
#    2340     max_combinations=max_combinations,
#    2341     max_conds_py=max_conds_py,
#    2342     max_conds_px=max_conds_px,
#    2343     max_conds_px_lagged=max_conds_px_lagged,
#    2344     )
#    2346 # Symmetrize p_matrix and val_matrix coming from skeleton
#    2347 symmetrized_results = self.symmetrize_p_and_val_matrix(
#    2348                     p_matrix=skeleton_results['p_matrix'],
#    2349                     val_matrix=skeleton_results['val_matrix'],
#    2350                     link_assumptions=links_for_pc,
#    2351                     conf_matrix=None)
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/pcmci.py:2971, in PCMCI._pcalg_skeleton(self, initial_graph, lagged_parents, mode, pc_alpha, tau_min, tau_max, max_conds_dim, max_combinations, max_conds_py, max_conds_px, max_conds_px_lagged)
#    2968     break
#    2970 # Run MCI test
# -> 2971 val, pval, Z, dependent = self._run_pcalg_test(graph=graph,
#    2972     i=i, abstau=abstau, j=j, S=S, lagged_parents=lagged_parents,
#    2973     max_conds_py=max_conds_py,
#    2974     max_conds_px=max_conds_px, max_conds_px_lagged=max_conds_px_lagged,
#    2975     tau_max=tau_max, alpha_or_thres=pc_alpha)
#    2977 # Store minimum absolute test statistic value for sorting adjt
#    2978 # (only internally used)
#    2979 val_min[j][(i, -abstau)] = min(np.abs(val),
#    2980                                val_min[j].get(
#    2981                                    (i, -abstau)))
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/jpcmciplus.py:825, in JPCMCIplus._run_pcalg_test(self, graph, i, abstau, j, S, lagged_parents, max_conds_py, max_conds_px, max_conds_px_lagged, tau_max, alpha_or_thres)
#     823     cond = list(S) + self.dummy_parents[j] + self.observed_context_parents[j]
#     824     cond = list(dict.fromkeys(cond))  # remove overlapps
# --> 825     return super()._run_pcalg_test(graph, i, abstau, j, cond, lagged_parents, max_conds_py,
#     826                                    max_conds_px, max_conds_px_lagged, tau_max, alpha_or_thres)
#     827 else:
#     828     return super()._run_pcalg_test(graph, i, abstau, j, S, lagged_parents, max_conds_py,
#     829                                    max_conds_px, max_conds_px_lagged, tau_max, alpha_or_thres)
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/pcmci.py:2763, in PCMCI._run_pcalg_test(self, graph, i, abstau, j, S, lagged_parents, max_conds_py, max_conds_px, max_conds_px_lagged, tau_max, alpha_or_thres)
#    2761     dependent = True
#    2762 else:
# -> 2763     val, pval, dependent = self.cond_ind_test.run_test(X=[(i, -abstau)], Y=[(j, 0)],
#    2764                                         Z=Z, tau_max=tau_max,
#    2765                                         alpha_or_thres=alpha_or_thres,
#    2766                                         )
#    2768 return val, pval, Z, dependent
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/independence_tests/independence_tests_base.py:414, in CondIndTest.run_test(self, X, Y, Z, tau_max, cut_off, alpha_or_thres)
#     411 if np.any(np.isnan(array)):
#     412     raise ValueError("nans in the array!")
# --> 414 combined_hash = self._get_array_hash(array, xyz, XYZ)
#     416 # Get test statistic value and p-value [cached if possible]
#     417 if combined_hash in self.cached_ci_results.keys():
#
# File ~/Documents/projects/ICA/ica-denoising/.venv/lib/python3.13/site-packages/tigramite/independence_tests/independence_tests_base.py:352, in CondIndTest._get_array_hash(self, array, xyz, XYZ)
#     349 y_hash = sha1(np.ascontiguousarray(arr_y)).hexdigest()
#     351 z_orderd = sorted(range(len(Z)), key=Z.__getitem__)
# --> 352 arr_z = array[xyz==2][z_orderd]
#     353 z_hash = sha1(np.ascontiguousarray(arr_z)).hexdigest()
#     355 sorted_xy = sorted([x_hash, y_hash])
#
# KeyboardInterrupt:

# %% [markdown]
# ## Manifest validation

# %%
if DRY_RUN:
    print("Dry run selected; no manifests were written.")
else:
    report = validate_benchmark(benchmark_root)
    print(f"Checked {report.checked} replicate(s).")
    if not report.ok:
        for error in report.errors:
            print(f"- {error}")
        raise RuntimeError("Simulation benchmark validation failed.")
    print("OK: manifest and output validation passed.")

# %% [markdown]
# ## Replicate manifest overview

# %%
manifest_rows = []
for manifest_path in sorted(benchmark_root.glob("*/seed_*/manifest.json")):
    manifest = json.loads(manifest_path.read_text())
    manifest_rows.append({
        "scenario": manifest.get("scenario_id"),
        "seed": manifest.get("seed"),
        "complete": manifest.get("complete"),
        "failures": len(manifest.get("failures", [])),
        "n_variants": manifest.get("n_variants"),
        "achieved_asr": manifest.get("achieved_asr"),
        "runtime_seconds": manifest.get("runtime_seconds"),
        "git_revision": manifest.get("git_revision"),
    })

manifest_table = pd.DataFrame(manifest_rows)
manifest_table

# %% [markdown]
# ## Rebuild summary tables

# %%
summary_dir.mkdir(parents=True, exist_ok=True)


def keep_main_graph_estimators(table: pd.DataFrame) -> pd.DataFrame:
    if table.empty or "estimator" not in table.columns:
        return table.copy()
    return table[table["estimator"].isin(MAIN_GRAPH_ESTIMATORS)].copy()


metric_tables = {}
for family in ("trace", "behavior", "state", "graph"):
    table = collect_metric_table(benchmark_root, family)
    metric_tables[family] = table
    table.to_csv(summary_dir / f"{family}_all.csv", index=False)
    print(f"{family}: {len(table)} row(s)")

graph_summary_all = summarize_graph_recovery(benchmark_root)
graph_paired_f1_all = paired_vs_raw(benchmark_root, metric="f1")
graph_summary = keep_main_graph_estimators(graph_summary_all)
graph_paired_f1 = keep_main_graph_estimators(graph_paired_f1_all)

graph_summary_all.to_csv(
    summary_dir / "graph_recovery_summary_all_estimators.csv", index=False
)
graph_paired_f1_all.to_csv(
    summary_dir / "graph_paired_vs_raw_all_estimators.csv", index=False
)
graph_summary.to_csv(summary_dir / "graph_recovery_summary.csv", index=False)
graph_paired_f1.to_csv(summary_dir / "graph_paired_vs_raw.csv", index=False)

if "estimator" in graph_summary_all.columns:
    all_estimators = set(graph_summary_all["estimator"].dropna().astype(str))
    main_estimators = set(graph_summary["estimator"].dropna().astype(str))
    excluded = sorted(all_estimators - main_estimators)
    if excluded:
        print(
            "Supplementary/internal estimator rows excluded from main summaries:",
            excluded,
        )

print(f"Wrote summaries to {summary_dir.relative_to(REPO_ROOT)}")
graph_summary.head(20)

# %% [markdown]
# ## Primary graph-recovery comparison

# %%
graph_all = metric_tables["graph"]
graph = keep_main_graph_estimators(graph_all)
if graph_all.empty:
    raise RuntimeError("No graph metrics found. Run the benchmark first.")
if graph.empty:
    raise RuntimeError(
        "No main graph metrics found for MAIN_GRAPH_ESTIMATORS. "
        "Check estimator outputs or adjust the manuscript-facing estimator filter."
    )

primary_columns = [
    "scenario",
    "estimator",
    "variant_id",
    "f1",
    "precision",
    "recall",
    "shd",
    "edge_density_bias",
    "jaccard_vs_reference",
]
available = [col for col in primary_columns if col in graph.columns]
(
    graph[available]
    .sort_values(["scenario", "estimator", "f1"], ascending=[True, True, False])
    .head(30)
)

# %%
figure_dir.mkdir(parents=True, exist_ok=True)

plot_data = graph_paired_f1[graph_paired_f1["variant_id"] != "raw"].copy()
if plot_data.empty:
    print("No paired graph data to plot.")
else:
    height = max(5, 0.35 * plot_data["variant_id"].nunique())
    g = sns.catplot(
        data=plot_data,
        kind="bar",
        x="f1_minus_raw",
        y="variant_id",
        hue="estimator",
        col="scenario",
        col_wrap=2,
        height=height,
        aspect=1.25,
        errorbar=None,
        sharex=True,
        sharey=False,
    )
    g.set_axis_labels("F1 minus raw", "Variant")
    g.set_titles("{col_name}")
    for ax in g.axes.flat:
        ax.axvline(0.0, color="black", linewidth=1)
    g.fig.suptitle("Paired graph-recovery effect relative to raw", y=1.02)
    out = figure_dir / "graph_f1_minus_raw.png"
    g.fig.savefig(out, dpi=200, bbox_inches="tight")
    if SHOW_FIGURES:
        plt.show()
    else:
        plt.close(g.fig)
    print(f"Saved {out.relative_to(REPO_ROOT)}")

# %% [markdown]
# ## Trace, behavior, and state trade-off table

# %%
trace = metric_tables["trace"]
behavior = metric_tables["behavior"]
state = metric_tables["state"]

trace_med = trace.groupby(["scenario", "variant_id"], as_index=False).agg(
    trace_pearson_global=("trace_pearson_global", "median"),
    trace_nrmse=("trace_nrmse", "median"),
    artifact_residual_corr=("artifact_residual_corr", "median"),
    effective_rank=("effective_rank", "median"),
)
behavior_med = behavior.groupby(["scenario", "variant_id"], as_index=False).agg(
    behavior_pearson=("behavior_pearson", "median"),
    bout_balanced_accuracy=("bout_balanced_accuracy", "median"),
)
state_med = state.groupby(["scenario", "variant_id"], as_index=False).agg(
    persistence_improvement=("persistence_improvement", "median"),
    forward_reverse_gap=("forward_reverse_gap", "median"),
    residual_artifact_assoc=("residual_artifact_assoc", "median"),
)
graph_med = graph.groupby(["scenario", "variant_id"], as_index=False).agg(
    graph_f1=("f1", "median"),
    graph_shd=("shd", "median"),
)

tradeoff = trace_med.merge(behavior_med, on=["scenario", "variant_id"], how="outer")
tradeoff = tradeoff.merge(state_med, on=["scenario", "variant_id"], how="outer")
tradeoff = tradeoff.merge(graph_med, on=["scenario", "variant_id"], how="outer")
tradeoff.to_csv(summary_dir / "trace_behavior_state_graph_tradeoff.csv", index=False)
tradeoff.sort_values(["scenario", "graph_f1", "trace_pearson_global"], ascending=[True, False, False]).head(30)

# %%
if tradeoff.empty:
    print("No trade-off data to plot.")
else:
    fig, ax = plt.subplots(figsize=(9, 6))
    sns.scatterplot(
        data=tradeoff,
        x="trace_pearson_global",
        y="graph_f1",
        hue="scenario",
        style="variant_id",
        s=90,
        ax=ax,
    )
    ax.set_xlabel("Trace recovery, median Pearson vs clean")
    ax.set_ylabel("Graph recovery, median F1")
    ax.set_title("Trace recovery versus graph recovery")
    ax.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
    out = figure_dir / "trace_vs_graph_recovery.png"
    fig.savefig(out, dpi=200, bbox_inches="tight")
    if SHOW_FIGURES:
        plt.show()
    else:
        plt.close(fig)
    print(f"Saved {out.relative_to(REPO_ROOT)}")

# %% [markdown]
# ## Benchmark audit flags

# %%
audit_flags = []
if cfg.estimator.correction == "fdr":
    audit_flags.append({
        "level": "review",
        "item": "FDR graph scoring",
        "note": "The c-GC adapter computes binary_fdr, but current runner outputs should be checked before treating FDR-corrected graphs as the scored primary graph.",
    })
if len(cfg.bss.random_states) > 1 or len(cfg.bss.ranks) > 1:
    audit_flags.append({
        "level": "review",
        "item": "BSS grid expansion",
        "note": "The config can list multiple ranks/seeds; verify the runner expands them before using core or robustness as final scientific runs.",
    })
if manifest_table.get("failures", pd.Series(dtype=int)).sum() > 0:
    audit_flags.append({
        "level": "blocker",
        "item": "Replicate failures",
        "note": "At least one manifest recorded failures. Inspect manifest['failures'] before using summaries.",
    })

pd.DataFrame(audit_flags)
